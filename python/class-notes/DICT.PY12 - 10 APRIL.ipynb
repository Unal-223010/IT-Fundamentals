# %% [markdown]
#     COLLECTION TYPES - DICTIONARIES :  Sözlük küme ayraçları 👉🏻 {} içine alınır. Her çift (öğe) virgülle ayrılır ve anahtar ve değer iki nokta üst üste ile ayrılir .(key,value pairs = item) { "KEY1" : VALUE1, .... }
#
#     - Dictionaries are used to store data values in key:value pairs.
#
#     - You cannot use iterables as keys to create a dictionary.( TUPLES OLABILIR. )
#
#     - A dictionary is a collection which is ordered*, changeable and does not allow duplicates.
#
#     - As of Python version 3.7, dictionaries are ordered. In Python 3.6 and earlier, dictionaries are unordered. (Ordered or Unordered?)
#
#     - Dictionaries are written with curly brackets, and have keys and values
#
#     -Changeable : Dictionaries are changeable, meaning that we can change, add or remove items after the dictionary has been created.
#
#     - Dictionaries cannot have two items with the same key
#
#     - To determine how many items a dictionary has, use the len() function
#
#     - The values in dictionary items can be of any data type
#
#     - type () : From Python's perspective, dictionaries are defined as objects with the data type 'dict'
#
#     - .get()
#
#     - .keys() : Keys objecti olusturur.Listeye cevirilebilir.
#
#     - .values() : Values objecti olusturur.Listeye cevirilebilir.
#
#     - .items() : Items objecti olusturur.Iterable yapiya sahipter. Itemler tuple tuple ayrilir.Listenin icinde tuplelar olusur.
#
#     - .update() : You have learned that you can add a new item by assigning value to a key that is not in the dictionary. Likewise, you can add new items using the
#
#     - del : You can also remove an item using the del function = del dictionary_name['key'].SOZLUGU TAMAMENDE SILEBILIR.
#
#     - Using the in and the not in operator, you can check if the key is in the dictionary.When we use the in operator; if the key is in the dictionary, the result will be True otherwise False.When we use the not in; if the key is not in the dictionary, the result will be True otherwise False.  ( in / not in operatorlerini kullanbiliriz. )
#
#     - .pop() : The pop() method removes the item with the specified key name
#
#     - .popitem() : The popitem() method removes the last inserted item (in versions before 3.7, a random item is removed instead)
#
#     - .clear() : The method empties the dictionary
#
#     - copy() :
#
#    EKSTRA BILGILER ICIN : https://docs.python.org/3.8/tutorial/datastructures.html#dictionaries
#
#                           http://www.veridefteri.com/2018/02/03/python-programlamaya-giris-sozluk-metodlari/
#
#                           https://www.mobilhanem.com/python-dictionarysozluk-ve-metotlari/
#
#                           https://www.sadikturan.com/python-objeleri-ve-veri-yapilari/python-dictionary/1379

# %% [markdown]
# ![Screen%20Shot%202021-05-14%20at%2014.45.18.jpg](attachment:Screen%20Shot%202021-05-14%20at%2014.45.18.jpg)

# %% [markdown]
# Q: What is a dictionary in Python?
# A: Python dictionary is one of the supported data types in Python. It is an unordered collection of elements. The elements in dictionaries are stored as key–value pairs. Dictionaries are indexed by keys. For example, below we have a dict named my_dict. It contains two keys, fruit and vegatable, along with their corresponding values, banana and onion.

# %%
dir(dict)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
# Creating a Dictionary

empty_dict_1 = {}
empty_dict_2 = dict()
print(empty_dict_1, empty_dict_2, type(empty_dict_1), len(empty_dict_1), sep = "\n")
# Out:
# {}
# {}
# <class 'dict'>
# 0

# %%
# Note that keys and values can be of different types. Key'ler str, int, bool, tuple olabilir, values hepsi olabilir.
# Key'lerin type genelde ayni olur.
mix_values = {'animal': ('dog', 'cat'),  # tuple type
              'planet': ['Neptun', 'Saturn', 'Jupiter'],  # list type
              'number': 40,  # int type
              'pi': 3.14,  # float type
              'is_good': True}  # bool type

mix_keys = {22 : "integer",
            1.2 : "float",
            True : "boolean",
            "key" : "string"}

# %%
# dict() fonksiyonu ile dict olusturken keysler variable gibi kullanilarak onlara " = " operatoruyle value assign edilir. 
grocer_1 = {"fruit" : "pomme", "boisson" : "l'eau"}
grocer_2 = dict(fruit = "pomme", boisson = "l'eau")
print(grocer_1)
print(grocer_2)
# Out:
# {'fruit': 'pomme', 'boisson': "l'eau"}
# {'fruit': 'pomme', 'boisson': "l'eau"}

# %%
canton = 'Vaud'                  # valueleri bir degiskene atayip oylede yapabiliriz.
canton_1 = 'Graubunden'
cantons = { 1 : canton, 2 : canton_1}
cantons
# Out:
# {1: 'Vaud', 2: 'Graubunden'}

# %%
print(cantons[1])
print(cantons[2])
print(type(cantons[2]))
print(type(cantons))
print(len(cantons))
# Out:
# Vaud
# Graubunden
# <class 'str'>
# <class 'dict'>
# 2

# %%
# Main Operations with Dictionaries
# Accessing Items : dict'lerde indekleme yapmak icin parantez icine key yazilir.

thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
x = thisdict["model"]
x
# Out:
# 'Mustang'

# %%
# There is also a method called GET() that will give you the same result
y = thisdict.get("model")
y
# Out:
# 'Mustang'

# %%
# The keys() method will return a list of all the keys in the dictionary.
v = thisdict.keys()
v
# Out:
# dict_keys(['brand', 'model', 'year'])

# %%
# The values() method will return a list of all the values in the dictionary.
z = thisdict.values()
z
# Out:
# dict_values(['Ford', 'Mustang', 1964])

# %%
car = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}

g = car.keys()

print(g) #before the change

car["color"] = "white"

print(g) #after the change
# Out:
# dict_keys(['brand', 'model', 'year'])
# dict_keys(['brand', 'model', 'year', 'color'])

# %%
car = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}

e = car.values()

print(e) #before the change

car["year"] = 2020

print(e) #after the change
# Out:
# dict_values(['Ford', 'Mustang', 1964])
# dict_values(['Ford', 'Mustang', 2020])

# %%
o = car.items()
o
# Out:
# dict_items([('brand', 'Ford'), ('model', 'Mustang'), ('year', 2020)])

# %%
# .update() metodu ile yeni bir items ekleyebiliriz.Birden fazla ekleme ve keys degerini degistirebiliriz.
# bu metod ile iki sozluk birlestirebiliriz.Var olan keyler guncellenir,olmayan eklenir. 
car.update({'hh': False})
car
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020, 'hh': False}

# %%
car.update({"brand" : 'Kia'})
car
# Out:
# {'brand': 'Kia', 'model': 'Mustang', 'year': 2020, 'hh': False}

# %%
# del fonksiyonunu kullanarak model keysini dict'ten sildik. SOZLUGU TAMAMENDE SILEBILIR.
del car['model'] 
car
# del car  = Bu komut olusturdugumuz sozlugu tamamen siler.
# Out:
# {'brand': 'Ford', 'year': 2020, 'hh': False}

# %%
del car['model'], car['hh'] # Birden fazla ogeyide silebiliriz.
car
# Out:
# {'brand': 'Kia', 'year': 2020}

# %%
# Dictionaryde if statement ve in opetoru kullanimi ornegi.
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
if "model" in thisdict:
  print("Yes, 'model' is one of the keys in the thisdict dictionary")
# Out:
# Yes, 'model' is one of the keys in the thisdict dictionary

# %%
print('year' in car)
print('model' not in car)
# Out:
# True
# True

# %%
for x, y in thisdict.items():
  print(x, y)
# Out:
# brand Ford
# model Mustang
# year 1964

# %%
for x in thisdict.keys():
  print(x)
# Out:
# brand
# model
# year

# %%
for x in thisdict.values():
  print(x)
# Out:
# Ford
# Mustang
# 1964

# %%
# .clear metodu sozlugumuzun icindeki itemsleri siler ve bos hale getirir.
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.clear()
print(thisdict)
# Out:
# {}

# %%
# Copy a Dictionary : You cannot copy a dictionary simply by typing dict2 = dict1, because: dict2 will only be a reference to dict1, and changes made in dict1 will automatically also be made in dict2.
#There are ways to make a copy, one way is to use the built-in Dictionary method copy().

thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
mydict = thisdict.copy()
print(mydict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
thisdict.clear()

# %%
mydict
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
mydict = dict(thisdict)
print(mydict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
thisdict.clear()

# %%
mydict
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
mydict = thisdict      # Bu sekilde yapilan kopyalama isleminde thisdict yapilan degisiklerler mydicti etkiler.
print(mydict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
del thisdict['year']
thisdict
# Out:
# {'brand': 'Ford', 'model': 'Mustang'}

# %%
mydict
# Out:
# {'brand': 'Ford', 'model': 'Mustang'}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Sozlukler value'lar uzerinden derinlesir.
school_records={
    "personal_info":
        {"kid":{"tom": {"class": "intermediate", "age": 10},
                "sue": {"class": "elementary", "age": 8}
               },
         "teen":{"joseph":{"class": "college", "age": 19},
                 "marry":{"class": "high school", "age": 16}
               },               
        },
        
    "grades_info":
        {"kid":{"tom": {"math": 88, "speech": 69},
                "sue": {"math": 90, "speech": 81}
               },
         "teen":{"joseph":{"coding": 80, "math": 89},
                 "marry":{"coding": 70, "math": 96}
               },               
        },        
}

school_records
# Out:
# {'personal_info': {'kid': {'tom': {'class': 'intermediate', 'age': 10},
#    'sue': {'class': 'elementary', 'age': 8}},
#   'teen': {'joseph': {'class': 'college', 'age': 19},
#    'marry': {'class': 'high school', 'age': 16}}},
#  'grades_info': {'kid': {'tom': {'math': 88, 'speech': 69},
#    'sue': {'math': 90, 'speech': 81}},
#   'teen': {'joseph': {'coding': 80, 'math': 89},
#    'marry': {'coding': 70, 'math': 96}}}}

# %%
list(school_records["grades_info"]["teen"]["joseph"].items())
# Out:
# [('coding', 80), ('math', 89)]

# %%
len(school_records)
# Out:
# 2

# %%
school_records={
    "personal_info":
        {"kid":{"tom": {"class":"intermediate", "age":10},
                "sue": {"class":"elementary", "age":8}
               },
         "teen":{"joseph":{"class":"college", "age":19},
                 "marry":{"class":"high school", "age":16}
               },               
        },
}

print(school_records['personal_info']['teen']['marry']['age'])
# Out:
# 16

# %%
print(school_records['personal_info'])
# Out:
# {'kid': {'tom': {'class': 'intermediate', 'age': 10}, 'sue': {'class': 'elementary', 'age': 8}}, 'teen': {'joseph': {'class': 'college', 'age': 19}, 'marry': {'class': 'high school', 'age': 16}}}

# %%
print(school_records['personal_info']['teen'])
# Out:
# {'joseph': {'class': 'college', 'age': 19}, 'marry': {'class': 'high school', 'age': 16}}

# %%
print(school_records['personal_info']['teen']['marry'])
# Out:
# {'class': 'high school', 'age': 16}

# %%
 child1 = {
  "name" : "Emil",
  "year" : 2004
}
child2 = {
  "name" : "Tobias",
  "year" : 2007
}
child3 = {
  "name" : "Linus",
  "year" : 2011
}

myfamily = {
  "child1" : child1,
  "child2" : child2,
  "child3" : child3
}

myfamily
# Out:
# {'child1': {'name': 'Emil', 'year': 2004},
#  'child2': {'name': 'Tobias', 'year': 2007},
#  'child3': {'name': 'Linus', 'year': 2011}}

# %%
len(myfamily)
# Out:
# 3

# %% [markdown]
# ![Screen%20Shot%202021-05-14%20at%2014.48.27.jpg](attachment:Screen%20Shot%202021-05-14%20at%2014.48.27.jpg)

# %%
friends = {
          'friend1' : {'fistname' : 'Ali', 'lastname' : 'GAA'},
          'friend2' : {'fistname' : 'Veli', 'lastname' : 'ASG'},
          'friend3' :  {'fistname' : 'HASAN', 'lastname' : 'HSDB'}
          }

len(friends)
# Out:
# 3

# %%
friends
# Out:
# {'friend1': {'fistname': 'Ali', 'lastname': 'GAA'},
#  'friend2': {'fistname': 'Veli', 'lastname': 'ASG'},
#  'friend3': {'fistname': 'HASAN', 'lastname': 'HSDB'}}

# %% [markdown]
#  JSON SYNTAX PHYTON arasitr.  https://www.w3schools.com/python/python_json.asp
